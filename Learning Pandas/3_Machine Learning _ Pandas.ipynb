# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/My Drive/Datasets/diamonds.csv", index_col=0)
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
cut_class_dict = {"Fair": 1, "Good": 2, "Very Good": 3, "Premium": 4, "Ideal": 5}
clarity_dict = {"I3": 1, "I2": 2, "I1": 3, "SI2": 4, "SI1": 5, "VS2": 6, "VS1": 7, "VVS2": 8, "VVS1": 9, "IF": 10, "FL": 11}
color_dict = {"J": 1,"I": 2,"H": 3,"G": 4,"F": 5,"E": 6,"D": 7}

df['cut'] = df['cut'].map(cut_class_dict)
df['clarity'] = df['clarity'].map(clarity_dict)
df['color'] = df['color'].map(color_dict)

df.head()
# Out:
#    carat  cut  color  clarity  depth  table  price     x     y     z
# 1   0.23    5      6        4   61.5   55.0    326  3.95  3.98  2.43
# 2   0.21    4      6        5   59.8   61.0    326  3.89  3.84  2.31
# 3   0.23    2      6        7   56.9   65.0    327  4.05  4.07  2.31
# 4   0.29    4      2        6   62.4   58.0    334  4.20  4.23  2.63
# 5   0.31    2      1        4   63.3   58.0    335  4.34  4.35  2.75

# %%
import sklearn
from sklearn import svm, preprocessing
from sklearn.linear_model import SGDRegressor

# %%
df = sklearn.utils.shuffle(df)

X = df.drop("price", axis=1).values
X = preprocessing.scale(X)
y = df["price"].values

test_size = 200

X_train = X[:-test_size]
y_train = y[:-test_size]

X_test = X[-test_size:]
y_test = y[-test_size:]
clf = svm.SVR(kernel='linear')
clf.fit(X_train, y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
clf.score(X_test, y_test)
# Out:
# 0.8840692178406088

# %%
for X,y in list(zip(X_test, y_test))[:10]:
    print(clf.predict([X])[0], y)
# Out:
# 2758.966330365921 2382
# 1892.1547530478106 1644
# 2477.2899209382863 2043
# 49.117740649830466 672
# 5140.078425218313 5353
# -170.47885372035262 776
# 2221.6012565953024 1898
# 3668.008564133756 2923
# 1356.0891062873702 1354
# 1017.776888530283 798

# %%
clf = svm.SVR()

clf.fit(X_train, y_train)
print(clf.score(X_test, y_test))
# Out:
# 0.6352229059875472

# %%
clf = SGDRegressor(max_iter=10000)

clf.fit(X_train, y_train)
print(clf.score(X_test, y_test))

for X,y in list(zip(X_test, y_test))[:10]:
    print(clf.predict([X])[0], y)
# Out:
# 0.9174528359662575
# 2769.0044425492406 2382
# 2154.292405933451 1644
# 1894.079001618315 2043
# -145.71151094294555 672
# 5410.850532510128 5353
# -509.8995749276123 776
# 1556.757090030936 1898
# 3452.157782175696 2923
# 1195.9300189770015 1354
# 1431.420368520768 798

# %%
import sklearn
from sklearn import svm, preprocessing

df = sklearn.utils.shuffle(df) # always shuffle your data to avoid any biases that may emerge b/c of some order.

X = df.drop("price", axis=1).values
X = preprocessing.scale(X)
y = df["price"].values

test_size = 200

X_train = X[:-test_size]
y_train = y[:-test_size]

X_test = X[-test_size:]
y_test = y[-test_size:]

clf = svm.SVR()

clf.fit(X_train, y_train)
print(clf.score(X_test, y_test))

for X,y in list(zip(X_test, y_test))[:10]:
    print(f"model predicts {clf.predict([X])[0]}, real value: {y}")
# Out:
# 0.5791214470068877
# model predicts 5133.294380334148, real value: 5637
# model predicts 785.9701344268087, real value: 552
# model predicts 3834.7935111130573, real value: 4409
# model predicts 1339.4412312996712, real value: 1410
# model predicts 3898.546810016268, real value: 3844
# model predicts 388.27879911573064, real value: 612
# model predicts 1614.5793689288087, real value: 1389
# model predicts 1011.5831884663876, real value: 477
# model predicts 6471.922431995208, real value: 16116
# model predicts 7313.337114528502, real value: 8024
